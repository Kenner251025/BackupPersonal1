# %% [markdown]
# <a href="https://colab.research.google.com/github/Kenner251025/BackupPersonal1/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("202603-PDE-REP-00401.csv")

# %%
df.head()
# Out:
#    ANIO  MES        ENTIDAD PRESTADORA  \
# 0  2019    1  TREN URBANO DE LIMA S.A.
# 1  2019    1  TREN URBANO DE LIMA S.A.
# 2  2019    1  TREN URBANO DE LIMA S.A.
# 3  2019    1  TREN URBANO DE LIMA S.A.
# 4  2019    1  TREN URBANO DE LIMA S.A.
#
#                                            CONCESION SIGLAS CONCESION  \
# 0  SISTEMA ELÉCTRICO DE TRANSPORTE MASIVO DE LIMA...              TL1
# 1  SISTEMA ELÉCTRICO DE TRANSPORTE MASIVO DE LIMA...              TL1
# 2  SISTEMA ELÉCTRICO DE TRANSPORTE MASIVO DE LIMA...              TL1
# 3  SISTEMA ELÉCTRICO DE TRANSPORTE MASIVO DE LIMA...              TL1
# 4  SISTEMA ELÉCTRICO DE TRANSPORTE MASIVO DE LIMA...              TL1
#
#                 ESTACION TIPO_PASAJERO                  TIPO_TARIFA  \
# 0  1.- VILLA EL SALVADOR        NORMAL  Intervalos en tarifa Adulto
# 1  1.- VILLA EL SALVADOR        NORMAL  Intervalos en tarifa Adulto
# 2  1.- VILLA EL SALVADOR        NORMAL  Intervalos en tarifa Adulto
# ...

# %%
df.shape
# Out:
# (94954, 11)

# %%
df.columns
# Out:
# Index(['ANIO', 'MES', 'ENTIDAD PRESTADORA', 'CONCESION', 'SIGLAS CONCESION',
#        'ESTACION', 'TIPO_PASAJERO', 'TIPO_TARIFA', 'TIPO_PASE',
#        'RANGO_HORARIO', 'CANTIDAD PASAJEROS'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94954 entries, 0 to 94953
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ANIO                94954 non-null  int64
#  1   MES                 94954 non-null  int64
#  2   ENTIDAD PRESTADORA  94954 non-null  object
#  3   CONCESION           94954 non-null  object
#  4   SIGLAS CONCESION    94954 non-null  object
#  5   ESTACION            94954 non-null  object
#  6   TIPO_PASAJERO       94954 non-null  object
#  7   TIPO_TARIFA         94954 non-null  object
#  8   TIPO_PASE           94954 non-null  object
#  9   RANGO_HORARIO       79010 non-null  object
#  10  CANTIDAD PASAJEROS  94954 non-null  int64
# dtypes: int64(3), object(8)
# memory usage: 8.0+ MB

# %%
df.isnull().sum()
# Out:
# ANIO                      0
# MES                       0
# ENTIDAD PRESTADORA        0
# CONCESION                 0
# SIGLAS CONCESION          0
# ESTACION                  0
# TIPO_PASAJERO             0
# TIPO_TARIFA               0
# TIPO_PASE                 0
# RANGO_HORARIO         15944
# CANTIDAD PASAJEROS        0
# dtype: int64

# %%
(df.isnull().sum() / len(df) * 100).round(2)
# Out:
# ANIO                   0.00
# MES                    0.00
# ENTIDAD PRESTADORA     0.00
# CONCESION              0.00
# SIGLAS CONCESION       0.00
# ESTACION               0.00
# TIPO_PASAJERO          0.00
# TIPO_TARIFA            0.00
# TIPO_PASE              0.00
# RANGO_HORARIO         16.79
# CANTIDAD PASAJEROS     0.00
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# np.int64(24)

# %%
df.describe()
# Out:
#                ANIO           MES  CANTIDAD PASAJEROS
# count  94954.000000  94954.000000        94954.000000
# mean    2022.319144      6.361923        11693.442835
# std        2.043168      3.502623        23975.836247
# min     2019.000000      1.000000            1.000000
# 25%     2021.000000      3.000000          381.000000
# 50%     2022.000000      6.000000         1945.000000
# 75%     2024.000000      9.000000        13973.500000
# max     2026.000000     12.000000       700585.000000
